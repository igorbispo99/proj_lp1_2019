# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("hmnist_rgb.csv")

# %%
df1 = df.drop('label', axis = 1)
df = pd.concat([df['label'], df1], axis=1)

# %%
df.to_csv("out.csv", header=False)

# %%
# Out:
#        label  pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  \
# 0          2        192        153        193        195        155
# 1          2         25         14         30         68         48
# 2          2        192        138        153        200        145
# 3          2         38         19         30         95         59
# 4          2        158        113        139        194        144
# 5          2          8          1          3         19          5
# 6          2        194        147        137        197        148
# 7          2        161        121        105        169        128
# 8          2        125         84         85        165        114
# 9          2        228        179        194        227        174
# 10         2         23         13         16         22         12
# 11         2        159        129        127        166        136
# 12         2         37         22         22        100         74
# ...

# %%
df.drop(df.columns[[2353]], axis=1)
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0            192        153        193        195        155        192
# 1             25         14         30         68         48         75
# 2            192        138        153        200        145        163
# 3             38         19         30         95         59         72
# 4            158        113        139        194        144        174
# 5              8          1          3         19          5         10
# 6            194        147        137        197        148        139
# 7            161        121        105        169        128        119
# 8            125         84         85        165        114        118
# 9            228        179        194        227        174        191
# 10            23         13         16         22         12         14
# 11           159        129        127        166        136        135
# ...

# %%
df.head()
# Out:
#    label  pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0      2        192        153        193        195        155        192
# 1      2         25         14         30         68         48         75
# 2      2        192        138        153        200        145        163
# 3      2         38         19         30         95         59         72
# 4      2        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  ...  pixel2343  pixel2344  pixel2345  \
# 0        197        154        185  ...        173        124        138
# 1        123         93        126  ...         60         39         55
# 2        201        142        160  ...        167        129        143
# 3        143        103        119  ...         44         26         36
# 4        215        162        191  ...        209        166        185
#
#    pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  pixel2351  label
# ...
